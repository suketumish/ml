# %% [markdown]
# ## Data Visualization using Matplotlib 📊

# %% [markdown]
# # Matplotlib
#
# **Matplotlib** is a Python plotting library which produces publication-quality figures in a variety of hardcopy formats and interactive environments across multiple platforms.
#
# Matplotlib tries to make **easy things easy** and **hard things possible**. You can generate:
#
# - Plots
# - Histograms
# - Power spectra
# - Bar charts
# - Error charts
# - Scatter plots
#
# — all with just a few lines of code.
#
# ---
#
# ## Matplotlib Modules
#
# The **matplotlib** library contains several useful modules:
#
# - `matplotlib.table` → tools for constructing tables
# - `matplotlib.text` → tools for including text in a figure
# - `matplotlib.colorbar` → allows visualization of scalar values in color
# - `matplotlib.pyplot` → designed to create colorful plots

# %% [markdown]
# # Table of Contents
#
# 1. [Installation](#installation)
# 2. [Getting Started With Pyplot](#getting-started-with-pyplot)
# 3. [World Population Graph](#world-population-graph)
# 4. [Adding Labels and Custom Line Color](#adding-labels-and-custom-line-color)
# 5. [Legends, Titles, and Labels](#legends-titles-and-labels)
# 6. [Multiple Lines and Line Styling](#multiple-lines-and-line-styling)
# 7. [Configuring the Graph](#configuring-the-graph)
# 8. [The Pie Chart](#the-pie-chart)
# 9. [The Doughnut Chart](#the-doughnut-chart)
# 10. [The Heatmap](#the-heatmap)
# 11. [The Bar Chart](#the-bar-chart)
# 12. [The Histogram](#the-histogram)
# 13. [The Scatter Plot](#the-scatter-plot)
# 14. [The Box Plot](#the-box-plot)
# 15. [The Stack Plot](#the-stack-plot)
# 16. [3D Graphs](#3d-graphs)
# 17. [3D Scatter Plot](#3d-scatter-plot)
# 18. [3D Bar Chart](#3d-bar-chart)
# 19. [Plotting Images](#plotting-images)

# %% [markdown]
# ## Installation
#
# Windows, Linux, and macOS distributions have **Matplotlib** and most of its dependencies available as wheel packages.
# Run the following command to install the Matplotlib package:
#
# ```bash
# pip install matplotlib
# ````
#
# ---
#
# # Importing Matplotlib
#
# You can import **Matplotlib** in two common ways:
#
# ```python
# from matplotlib import pyplot as plt
# ```
#
# or
#
# ```python
# import matplotlib.pyplot as plt

# %% [markdown]
# ## Import Essential Packages

# %%
import numpy as np
import pandas as pd 
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

import os
# os.listdir('../input')

# %%
read_csv = pd.read_csv('student_scores.csv')
print(read_csv)
# Out:
#     Name  Score  Age
# 0     A1     97   24
# 1     B1     82   21
# 2     C1     96   24
# 3     D1     93   19
# 4     E1     65   20
# ..   ...    ...  ...
# 495  B20     62   21
# 496  C20     64   22
# 497  D20     66   21
# 498  E20     78   24
# 499  F20     72   21
#
# [500 rows x 3 columns]

# %% [markdown]
# # Getting Started With Pyplot
#
# **Pyplot** is a Matplotlib module that provides simple functions for adding plot elements, such as lines, images, text, etc., to the axes in the current figure.
#
# Let's begin with a simple graph using fundamental Matplotlib code:
#
# ```python
# fig, ax = plt.subplots()  # this creates a figure paired with axes

# %%
fig, ax = plt.subplots()
# x data
x = np.linspace(15, 10)
# y data
y = np.sin(x) + x
# creates the plot
ax.plot(x, y)                
# this will show your plot in case your environment is not interactive
fig.show()
# Out:
# C:\Users\saket\AppData\Local\Temp\ipykernel_14668\3867879398.py:9: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
color = 'r'
linestyle = 'dashed'
linewidth = 4
fig, ax = plt.subplots(figsize=(15,10))
fig.suptitle('Our First plot', fontsize=40)
ax.plot(x, y, c=color, linestyle=linestyle, linewidth=linewidth)
plt.show()

# %%
ax.set_ylabel('function', fontsize = 30)
ax.set_xlabel('argument', fontsize = 30)
# Out:
# Text(0.5, 4.4444444444444375, 'argument')

# %%
fig, ax = plt.subplots(figsize=(12,7))
fig.suptitle('Our First plot', fontsize=30)
ax.plot(x, y, c=color, linestyle=linestyle, linewidth=linewidth)
ax.set_ylabel('function', fontsize = 30)
ax.set_xlabel('argument', fontsize = 30)
for xtick in ax.xaxis.get_major_ticks():
    xtick.label1.set_fontsize(18)

for ytick in ax.yaxis.get_major_ticks():
    ytick.label1.set_fontsize(34)
plt.show()

# %%
fig, axes = plt.subplots(1, 3, figsize=(16,8))
ax1, ax2, ax3 = axes
x = np.linspace(0,10,500)
y1 = np.sin(x)
y2 = np.cos(x)
y3 = np.tan(x)

ax1.set_ylabel('sin(x)', fontsize=30)
ax1.set_xlabel('x', fontsize=30)
ax2.set_ylabel('cos(x)', fontsize=30)
ax2.set_xlabel('x', fontsize=30)
ax3.set_ylabel('tan(x)', fontsize=30)
ax3.set_xlabel('x', fontsize=30)
fig.tight_layout(pad=2)

ax1.plot(x, y1, c='r', linewidth=4)
ax2.plot(x, y2, c='g', linewidth=4)
ax3.plot(x, y3, c='b', linewidth=4)
plt.show()

# %% [markdown]
# ## World population graph

# %%
years=[1,1000,1500,1600,1700,1750,1800,1850,1900,1950,1955,1960,1965,1970,1980,1985,1990,
       1995,2000,2005,2010,2015]
pops=[200,400,458,580,682,791,1000,1262,1650,2525,2758,3018,3322,3682,
      4061,4440,4853,5310,5735,6127,6520,7349]
plt.plot(years,pops)
plt.show()

# %% [markdown]
# ## Adding labels and custom line color

# %%
years=[1950,1955,1960,1965,1970,1980,1985,1990,1995,2000,2005,2010,2015]
pops=[2.5,2.7,3.0,3.3,3.6,4.0,4.4,4.8,5.3,5.7,6.1,6.5,7.3]
plt.plot(years,pops,color=(255/255,100/255,100/255))
plt.ylabel("Population in Billions")
plt.xlabel("Population growth by year")
plt.title("Population Growth")
plt.show()

# %%
x = [1,6,3]
y = [5,9,4]

x2 = [1,2,3]
y2 = [10,14,12]

plt.plot(x, y, label='First Line')
plt.plot(x2, y2, label='Second Line')
plt.xlabel('Plot Number')
plt.ylabel('Important var')
plt.title('Interesting Graph Check it out')
plt.legend()
plt.show()

# %%
years=[1950,1955,1960,1965,1970,1980,1985,1990,1995,2000,2005,2010,2015]
pops=[2.5,2.7,3.0,3.3,3.6,4.0,4.4,4.8,5.3,5.7,6.1,6.5,7.3]
death=[1.2,1.1,1.2,2.1,2.0,2.3,1.8,1.9,2.6,1.6,2.4,2.4,4.0]
plt.plot(years,pops,'--',color=(255/255,100/255,100/255))
plt.plot(years,death,color=(.6,.6,1))
plt.ylabel("Population in Billions")
plt.xlabel("Population growth by year")
plt.title("Population Growth")
plt.show()

# %%
years=[1950,1955,1960,1965,1970,1980,1985,1990,1995,2000,2005,2010,2015]
pops=[2.5,2.7,3.0,3.3,3.6,4.0,4.4,4.8,5.3,5.7,6.1,6.5,7.3]
death=[1.2,1.1,1.2,2.1,2.0,2.3,1.8,1.9,2.6,1.6,2.4,2.4,4.0]
lines=plt.plot(years,pops,years,death)
plt.grid(True)
plt.setp(lines,color=(1,.4,.5),marker='*')
plt.show()

# %% [markdown]
# ## The Pie Chart
#
# A **pie chart** is a circular plot that shows how data items relate to one another. The total area of the pie chart represents **100% of the data**, and the area of slices (also called **wedges**) represents the percentage of individual data parts. Pie charts are especially useful when we need to **compare parts of a whole**.
#
# ---
#
# ## Creating a Pie Chart
#
# To create a pie chart using Matplotlib, you can use the `pie()` function:
#
# ```python
# plt.pie(data)
# ````
#
# Here, `data` is an array of values that you want to plot.
#
# ### Optional Parameters of `plt.pie()`
#
# Some commonly used optional parameters include:
#
# * `explode` → allows separating slices of a pie chart
# * `labels` → a list of strings to label each corresponding slice
# * `labeldistance` → radial distance at which pie labels are drawn (default is 1.1)
# * `colors` → colors of the slices
# * `shadow` → adds a shadow effect to the pie chart
# * `startangle` → chooses the starting angle of the plot
# * `wedgeprops` → customize various slice parameters
# * `radius` → sets the radius of the circle (default is 1)
#
# ---

# %%
data=[33,52,12,17,42,48]
plt.pie(data)
plt.show()

# %%
labels=['Python','C','C++','PHP','Java','Ruby']
plt.pie(data,labels=labels)
plt.show()

# %%
plt.figure(figsize=(9, 7))
plt.pie(data)
plt.title('The results of the programming language survey', fontsize=14)
plt.legend(labels)
plt.show()

# %%
explode = [0.0, 0.08, 0.0, 0.0,0.0,0.0]
plt.pie(data, explode=explode, labels=labels)
plt.show()

# %% [markdown]
# # Colors and shadows
# * To make our graph even more illustrative, we can pass a list of colors to the color parameter and add a shadow underneath by setting the shadow to True:

# %%
colors = ['saddlebrown', 'wheat', 'crimson', 'lightgrey','lightblue','darkblue']
plt.pie(data, 
        explode=explode, 
        labels=labels, 
        colors=colors, 
        shadow=True)
plt.show()

# %% [markdown]
# ## Display the value
# * The autopct parameter displays the percent value on the slices. If autopct is %.2f, then for each pie slice, the format string is %.2f, where %is a special character that tells when to type the value, f sets the result to be a floating-point type, and the .2 sets a limit to only 2 digits after the point.

# %%
plt.pie(data, 
        explode=explode, 
        labels=labels, 
        colors=colors, 
        autopct='%.2f%%',    # here we also add the % sign 
        shadow=True)
plt.show()

# %% [markdown]
# # Starting Angle in Pie Charts
#
# By default, pie charts are plotted from the **x-axis**, and slices are drawn **counterclockwise**.
#
# The `startangle` parameter allows you to define the angle where you want the pie chart to start. The default angle is `0`.
#
# You can also control the drawing direction of the slices using the `counterclock` parameter, which is **True by default** (i.e., slices are drawn counterclockwise).
#
# ---
#
# ## Example: Starting Slices at 90 Degrees
#
# If we want the slices to start at **90 degrees**, we can set:
#
# ```python
# plt.pie(data, startangle=90)

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 6))
ax1, ax2 = axes

ax1.pie(data, labels=labels, colors=colors, startangle=90)
ax2.pie(data, labels=labels, colors=colors, startangle=90, counterclock=False)
ax1.set_title('Starting the plot at 90°')
ax2.set_title('Plotting clockwise')
plt.show()

# %% [markdown]
# # The Doughnut Chart
#
# A **doughnut chart** is very similar to a pie chart. However, since a doughnut chart has an **opening at the center**, it makes the slices appear more like bars.
#
# Matplotlib does **not provide a dedicated method** for plotting doughnut charts.
# However, we can use the `wedgeprops` parameter in the `plt.pie()` function to define the **width of the wedges** and create a doughnut effect:
#
# ```python
# plt.pie(data, wedgeprops={'width': 0.4})

# %% [markdown]
# I can continue and write a **full example with labels, colors, and a proper doughnut chart plot** in Markdown for your tutorial. Do you want me to do that?

# %%
plt.pie(data, 
        labels=labels, 
        colors=colors, 
        startangle=90, 
        wedgeprops={'width': 0.2})
plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 6))
width = 0.3

p_pie = ax.pie(data,radius=1,labels=labels, colors=colors,wedgeprops = {'width': width})

pets_data = [45, 41, 10, 4]
pets_labels = ['Apple', 'Carrot', 'Banana', 'Other']
pets_colors = ['orange', 'teal', 'powderblue', 'green']
pets_pie = ax.pie(pets_data, 
                  radius=1-width, 
                  labels=pets_labels,
                  labeldistance=0.7, 
                  colors=pets_colors, 
                  wedgeprops = {'width': width})

plt.show()

# %%
fig, ax = plt.subplots(figsize=(8, 6))
width = 0.3

p_pie = ax.pie(data,radius=1,labels=labels, colors=colors,wedgeprops = {'width': width})

pets_data = [45, 41, 10, 4]
pets_labels = ['Apple', 'Carrot', 'Banana', 'Other']
pets_colors = ['orange', 'teal', 'powderblue', 'green']
pets_pie = ax.pie(pets_data, 
                  radius=1-width, 
                  labels=pets_labels,
                  labeldistance=0.7, 
                  colors=pets_colors, 
                  wedgeprops = {'width': width})

plt.show()
